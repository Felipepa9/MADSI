# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipepa9/MADSI/blob/main/ENTREGA_FINAL_CIENCIA_DE_DATOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/CIENCIA DE DATOS/PROYECTO_FINAL.csv')
data.head()
# Out:
#   scheduled_flight_leg_block_off_date scheduled_flight_leg_block_off_time  \
# 0                          2024-12-12                            06:01:00
# 1                          2024-12-12                            10:10:00
# 2                          2024-12-12                            13:44:00
# 3                          2024-12-12                            09:55:00
# 4                          2024-12-12                            12:42:00
#
#   scheduled_flight_leg_block_off_date_utc  \
# 0                              2024-12-12
# 1                              2024-12-12
# 2                              2024-12-12
# 3                              2024-12-12
# 4                              2024-12-12
#
#   scheduled_flight_leg_block_off_time_utc marketing_airline_code  \
# 0                                09:01:00                     LA
# 1                                13:10:00                     LA
# 2                                16:44:00                     LA
# 3                                12:55:00                     LA
# 4                                17:42:00                     LA
#
#    operating_flight_num origin_leg_iata_airport_code  \
# 0                   716                          SCL
# 1                   285                          SCL
# 2                   156                          SCL
# 3                    71                          SCL
# 4                  4401                          MIA
#
#   destination_leg_iata_airport_code flight_leg_registration_code  \
# 0                               FLN                        PTXPO
# 1                               PMC                        CCBEL
# 2                               CJC                        CCBEG
# 3                               BBA                        CCCOH
# 4                               BOG                        CCBFE
#
#   actual_flight_leg_fleet_name  ... cant_pasajeros_totales_sum_last_30_days  \
# 0                         A321  ...                                 70790.0
# 1                         A321  ...                                400904.0
# 2                         A321  ...                                426426.0
# 3                         A320  ...                                156793.0
# 4                         A320  ...                                 76060.0
#
#   payload_max_avg_last_30_days payload_max_sum_last_30_days  PESO_1_BAG  \
# 0                     12705.77                    8482835.0   14.302730
# 1                     11810.37                   43742858.0   14.822279
# 2                     13915.23                   51355562.0   13.607188
# 3                     11034.83                   16399930.0   15.635410
# 4                     11201.99                    8278868.0   16.720161
#
#    PESO_1_PAX  CANT_BAGS_POR_PAX  CANT_BAGS_TOTALES  \
# 0   75.264939           0.526218          64.745911
# 1   78.401316           0.447950          57.243547
# 2   82.615922           0.460153          59.879648
# 3   78.897119           0.598337          75.815238
# 4   81.882566           1.118183         135.579690
#
#    PESO_BAGS_POR_PAX_BOOKEADOS  PESO_PAX_BOOKEADOS  POS_USADAS_POR_EQUIPAJE
# 0                        926.0              9261.0                      0.0
# 1                        848.0             10019.0                      0.0
# 2                        815.0             10751.0                      0.0
# 3                       1185.0              9997.0                      0.0
# 4                       2267.0              9928.0                      0.0
#
# [5 rows x 34 columns]

# %%
data.isnull().sum()
# Out:
# scheduled_flight_leg_block_off_date           0
# scheduled_flight_leg_block_off_time           0
# scheduled_flight_leg_block_off_date_utc       0
# scheduled_flight_leg_block_off_time_utc       0
# marketing_airline_code                        0
# operating_flight_num                          0
# origin_leg_iata_airport_code                  0
# destination_leg_iata_airport_code             0
# flight_leg_registration_code                 54
# actual_flight_leg_fleet_name                 54
# actual_flight_leg_fleet_name_code            54
# FLIGHT_KEY_PLANNING                          54
# FLIGHT_KEY_PAX                                0
# POS_DISP_TOTALES                              0
# total_pax_qty                              1019
# total_capacity_leg_qty                     1019
# fo_pct                                     1019
# peso_pasajeros_avg_last_30_days             442
# peso_pasajeros_sum_last_30_days             442
# cant_bags_sum_last_30_days                  442
# peso_bags_sum_last_30_days                  442
# cant_bags_avg_last_30_days                  442
# peso_bags_avg_last_30_days                  442
# cant_pasajeros_totales_avg_last_30_days     442
# cant_pasajeros_totales_sum_last_30_days     442
# payload_max_avg_last_30_days                442
# payload_max_sum_last_30_days                442
# PESO_1_BAG                                    0
# PESO_1_PAX                                    0
# CANT_BAGS_POR_PAX                             0
# CANT_BAGS_TOTALES                             0
# PESO_BAGS_POR_PAX_BOOKEADOS                   0
# PESO_PAX_BOOKEADOS                            0
# POS_USADAS_POR_EQUIPAJE                       0
# dtype: int64
